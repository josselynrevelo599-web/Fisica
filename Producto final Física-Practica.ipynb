# %% [markdown]
# ## Proyecto Final Física - Práctica

# %%
pip install gradio
# Out:
# Requirement already satisfied: gradio in c:\users\usuario\anaconda3\lib\site-packages (6.0.2)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (4.7.0)
# Requirement already satisfied: audioop-lts<1.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.124.0)
# Requirement already satisfied: ffmpy in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (2.0.1)
# Requirement already satisfied: groovy~=0.1 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (1.2.1)
# Requirement already satisfied: jinja2<4.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (3.0.2)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (3.11.5)
# Requirement already satisfied: packaging in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (2.2.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (11.1.0)
# Requirement already satisfied: pydantic<=2.12.4,>=2.11.10 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (2.12.4)
# Requirement already satisfied: pydub in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (6.0.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in c:\users\usuario\anaconda3\lib\site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in c:\users\usuario\anaconda3\lib\site-packages (from gradio-client==2.0.1->gradio) (2025.3.2)
# Requirement already satisfied: idna>=2.8 in c:\users\usuario\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\usuario\anaconda3\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\usuario\anaconda3\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in c:\users\usuario\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\usuario\anaconda3\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\usuario\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in c:\users\usuario\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.17.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\usuario\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.5.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\usuario\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\usuario\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\usuario\anaconda3\lib\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\usuario\anaconda3\lib\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\usuario\anaconda3\lib\site-packages (from pydantic<=2.12.4,>=2.11.10->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Requirement already satisfied: rich>=10.11.0 in c:\users\usuario\anaconda3\lib\site-packages (from typer<1.0,>=0.12->gradio) (13.9.4)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\usuario\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\usuario\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install voila
# Out:
# Requirement already satisfied: voila in c:\users\usuario\anaconda3\lib\site-packages (0.5.11)
# Requirement already satisfied: jupyter-client<9,>=7.4.4 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (8.6.3)
# Requirement already satisfied: jupyter-core>=4.11.0 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (5.7.2)
# Requirement already satisfied: jupyter-server<3,>=1.18 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.3.0 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (2.27.3)
# Requirement already satisfied: nbclient>=0.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (0.10.2)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (7.16.6)
# Requirement already satisfied: traitlets<6,>=5.0.3 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (5.14.3)
# Requirement already satisfied: websockets>=9.0 in c:\users\usuario\anaconda3\lib\site-packages (from voila) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-client<9,>=7.4.4->voila) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (3.1.6)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (24.2)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-server<3,>=1.18->voila) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\usuario\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\usuario\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\usuario\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.3.0->voila) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (3.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\usuario\anaconda3\lib\site-packages (from nbconvert<8,>=6.4.5->voila) (2.19.1)
# Requirement already satisfied: idna>=2.8 in c:\users\usuario\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\usuario\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\usuario\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\usuario\anaconda3\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-core>=4.11.0->voila) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-core>=4.11.0->voila) (308)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\usuario\anaconda3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (2.1)
# Requirement already satisfied: uri-template in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\usuario\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (25.10.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\usuario\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.18->voila) (2.20.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client<9,>=7.4.4->voila) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.3.0->voila) (2025.11.12)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\usuario\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\usuario\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=1.18->voila) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\usuario\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\usuario\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.18->voila) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Requirement already satisfied: ipywidgets in c:\users\usuario\anaconda3\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\usuario\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\usuario\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing in c:\users\usuario\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\usuario\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\usuario\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run script server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
# !pip install ipywidgets jupyterlab_widgets
# Out:
# Requirement already satisfied: ipywidgets in c:\users\usuario\anaconda3\lib\site-packages (8.1.5)
# Requirement already satisfied: jupyterlab_widgets in c:\users\usuario\anaconda3\lib\site-packages (3.0.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\usuario\anaconda3\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: decorator in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\usuario\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\usuario\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\usuario\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: executing in c:\users\usuario\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\usuario\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\usuario\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)

# %%
pip install jupyterlab_widgets
# Out:
# Requirement already satisfied: jupyterlab_widgets in c:\users\usuario\anaconda3\lib\site-packages (3.0.13)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ipywidgets as widgets
from IPython.display import display, clear_output

# Widgets
masa_input = widgets.FloatSlider(value=5, min=0.5, max=50, step=0.1, description="Masa (kg)")
angulo_input = widgets.FloatSlider(value=30, min=0, max=60, step=0.1, description="Ángulo (°)")
mu_input = widgets.FloatSlider(value=0.3, min=0, max=1, step=0.01, description="Coef. fricción μ")
button = widgets.Button(description="Simular")
output = widgets.Output()

def simular(b):
    with output:
        clear_output()
        
        m = masa_input.value
        theta = np.radians(angulo_input.value)
        mu = mu_input.value
        g = 9.81
        
        # Fuerzas
        P = m * g
        F_paralela = P * np.sin(theta)
        N = P * np.cos(theta)
        F_friccion = mu * N
        
        # Estado del objeto
        if F_paralela > F_friccion:
            estado = "El objeto SE DESLIZA"
            aceleracion = (F_paralela - F_friccion) / m
        else:
            estado = "El objeto PERMANECE EN REPOSO"
            aceleracion = 0.0
        
        # Gráfico
        fig, ax = plt.subplots()
        
        # Dibujar plano inclinado
        ax.plot([0, np.cos(theta)], [0, np.sin(theta)], 'k-', linewidth=2)
        
        # Dibujar cuadrado apoyado sobre el plano
        size = 0.2  # tamaño del cuadrado
        # Punto de apoyo (mitad de la línea negra)
        cx, cy = 0.5*np.cos(theta), 0.5*np.sin(theta)
        
        # Crear cuadrado con rotación
        square = patches.Rectangle(
            (0, 0), size, size,
            angle=np.degrees(theta),
            facecolor="gray", edgecolor="black"
        )
        
        # Trasladar el cuadrado para que su lado inferior quede sobre la línea
        # Lo movemos de manera que su base esté en (cx, cy)
        t = (plt.matplotlib.transforms.Affine2D()
             .rotate(theta)  # rotar según el ángulo
             .translate(cx, cy)  # trasladar al punto de apoyo
             + ax.transData)
        
        square.set_transform(t)
        ax.add_patch(square)
        
        # Vectores de fuerzas
        ax.arrow(cx, cy, 0, -P/50,
                 head_width=0.05, color='blue', label="Peso")
        
        ax.arrow(cx, cy, -F_friccion/50*np.cos(theta), -F_friccion/50*np.sin(theta),
                 head_width=0.05, color='red', label="Fricción")
        
        ax.arrow(cx, cy, F_paralela/50*np.cos(theta), F_paralela/50*np.sin(theta),
                 head_width=0.05, color='green', label="Componente paralela")
        
        ax.set_aspect('equal')
        ax.set_xlim(-1, 2)
        ax.set_ylim(-1, 2)
        ax.set_title("Simulación de plano inclinado con fricción")
        ax.legend()
        ax.grid(True)
        display(fig)
        
        print(f"Peso: {m*9.8:.2f} kg")
        print(f"Ángulo: {np.degrees(theta):.2f}°")
        print(f"Coef. fricción μ: {mu:.2f}")
        print(f"Fuerza paralela: {F_paralela:.2f} N")
        print(f"Fuerza de fricción: {F_friccion:.2f} N")
        print(f"Aceleración: {aceleracion:.2f} m/s²")
        print(f"Estado: {estado}")

button.on_click(simular)
display(masa_input, angulo_input, mu_input, button, output)
# Out:
# FloatSlider(value=5.0, description='Masa (kg)', max=50.0, min=0.5)
# FloatSlider(value=30.0, description='Ángulo (°)', max=60.0)
# FloatSlider(value=0.3, description='Coef. fricción μ', max=1.0, step=0.01)
# Button(description='Simular', style=ButtonStyle())
# Output()
